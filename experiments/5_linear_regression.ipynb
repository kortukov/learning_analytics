# %%
import os
os.chdir('..')
os.getcwd()
# Out:
# 'E:\\git_projects\\ML Masters\\Data Literacy\\Project\\learning_analytics'

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from src import config


from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_validate
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler


# %load_ext autoreload
# %autoreload 2

pd.set_option('display.max_columns', 200)

# %%
df = pd.read_csv('data/preprocessed_data.csv')

# %%
df.tail()
# Out:
#        ISU_ID  GENDER  ADMITTED_EXAMS_SUM  RUSSIAN_LANG  MATH  PHYSICS  \
# 20569  265000       1               286.0          98.0  88.0     86.0
# 20570  243784       1               247.0          86.0  78.0     80.0
# 20571  265389       0               257.0          91.0  82.0     86.0
# 20572  242366       1               252.0          86.0  72.0     86.0
# 20573  265375       1               246.0          85.0  78.0     86.0
#
#        CHEMISTRY  FOREIGN_LANG  INFORMATICS  SOCIAL_STUDIES  REGION_ID  \
# 20569       86.0          88.0        100.0            78.0       78.0
# 20570       79.0          88.5         84.0            66.0        NaN
# 20571       86.0          88.0         84.0            78.0       75.0
# 20572       86.0          88.0        100.0            78.0        2.0
# 20573       86.0          88.0         83.0            78.0       69.0
#
#       CURRENT_STATUS  DROPPED_BEFORE  START_YEAR  AGE_AT_START  HONS_TARGET  \
# 20569         обучен             0.0  2018-09-01          18.0          0.0
# 20570         диплом             0.0  2017-09-01          17.0          0.0
# 20571         обучен             0.0  2018-09-01          18.0          0.0
# 20572         обучен             0.0  2018-09-01          18.0          0.0
# 20573         обучен             0.0  2018-09-01          17.0          0.0
#
#        DROPPED_TARGET  MARKS_MEAN_SEM_1  MARKS_MEAN_SEM_2  PROGRAM_01  \
# 20569             NaN              4.20          4.500000           1
# 20570             1.0              3.75          4.428571           0
# 20571             NaN              4.75          5.000000           0
# 20572             NaN              4.00          3.000000           1
# 20573             NaN              4.50          4.666667           0
#
#        PROGRAM_09  PROGRAM_10  PROGRAM_11  PROGRAM_12  PROGRAM_13  PROGRAM_14  \
# 20569           0           0           0           0           0           0
# 20570           0           0           0           0           0           0
# 20571           0           0           0           1           0           0
# 20572           0           0           0           0           0           0
# 20573           0           0           0           1           0           0
#
#        PROGRAM_15  PROGRAM_16  PROGRAM_18  PROGRAM_19  PROGRAM_23  PROGRAM_24  \
# 20569           0           0           0           0           0           0
# 20570           0           0           0           0           0           0
# 20571           0           0           0           0           0           0
# 20572           0           0           0           0           0           0
# 20573           0           0           0           0           0           0
#
#        PROGRAM_27  PROGRAM_38  PROGRAM_44  PROGRAM_45  \
# 20569           0           0           0           0
# 20570           0           0           0           0
# 20571           0           0           0           0
# 20572           0           0           0           0
# 20573           0           0           0           0
#
#        ADMISSION_COND_без вступительных испытаний  \
# 20569                                           0
# 20570                                           0
# 20571                                           0
# 20572                                           1
# 20573                                           0
#
#        ADMISSION_COND_на бюджетное место в пределах особой квоты  \
# 20569                                                  0
# 20570                                                  0
# 20571                                                  0
# 20572                                                  0
# 20573                                                  0
#
#        ADMISSION_COND_на бюджетное место в пределах целевой квоты  \
# 20569                                                  0
# 20570                                                  0
# 20571                                                  0
# 20572                                                  0
# 20573                                                  0
#
#        ADMISSION_COND_на выделенное бюджетное место (для жителей Крыма)  \
# 20569                                                  0
# 20570                                                  0
# 20571                                                  0
# 20572                                                  0
# 20573                                                  0
#
#        ADMISSION_COND_на контрактной основе  \
# 20569                                     0
# 20570                                     0
# 20571                                     0
# 20572                                     0
# 20573                                     0
#
#        ADMISSION_COND_по общему конкурсу  RUSSIAN_LANG_BIN  MATH_BIN  \
# 20569                                  1                 1         1
# 20570                                  0                 0         0
# 20571                                  1                 1         1
# 20572                                  0                 1         1
# 20573                                  1                 1         1
#
#        PHYSICS_BIN  CHEMISTRY_BIN  FOREIGN_LANG_BIN  INFORMATICS_BIN  \
# 20569            0              0                 0                1
# 20570            0              0                 0                0
# 20571            1              0                 0                1
# 20572            0              0                 0                1
# 20573            0              0                 0                1
#
#        SOCIAL_STUDIES_BIN  Русский язык  Математика  Биология  \
# 20569                   0             1           0         0
# 20570                   0             0           0         0
# 20571                   0             1           0         0
# 20572                   0             0           0         0
# 20573                   0             1           0         0
#
#        Иностранный язык  Физика  Информатика  nan  Обществознание  Химия  \
# 20569                 0       0            0    0               0      0
# 20570                 0       0            0    1               0      0
# 20571                 0       0            0    0               0      0
# 20572                 0       0            1    0               0      0
# 20573                 0       0            0    0               0      0
#
#        ADMISSION_TYPE_100 баллов за олимпиаду  ADMISSION_TYPE_ЕГЭ  \
# 20569                                       0                   1
# 20570                                       0                   0
# 20571                                       0                   1
# 20572                                       1                   0
# 20573                                       0                   1
#
#        ADMISSION_TYPE_nan  ADMITTED_SUBJECT_PRIZE_LEVEL_0.0  \
# 20569                   0                                 0
# 20570                   1                                 0
# 20571                   0                                 0
# 20572                   0                                 0
# 20573                   0                                 0
#
#        ADMITTED_SUBJECT_PRIZE_LEVEL_1.0  ADMITTED_SUBJECT_PRIZE_LEVEL_2.0  \
# 20569                                 0                                 0
# 20570                                 0                                 0
# 20571                                 0                                 0
# 20572                                 1                                 0
# 20573                                 0                                 0
#
#        ADMITTED_SUBJECT_PRIZE_LEVEL_3.0  ADMITTED_SUBJECT_PRIZE_LEVEL_4.0  \
# 20569                                 0                                 1
# 20570                                 0                                 0
# 20571                                 0                                 1
# 20572                                 0                                 0
# 20573                                 0                                 1
#
#        ADMITTED_SUBJECT_PRIZE_LEVEL_nan  ADMITTED_EXAMS_SUM_BIN  \
# 20569                                 0                       1
# 20570                                 1                       0
# 20571                                 0                       1
# 20572                                 0                       1
# 20573                                 0                       1
#
#        NATIONALITY_Белоруссия  NATIONALITY_Вьетнам  NATIONALITY_КНР  \
# 20569                       0                    0                0
# 20570                       1                    0                0
# 20571                       0                    0                0
# 20572                       0                    0                0
# 20573                       0                    0                0
#
#        NATIONALITY_Казахстан  NATIONALITY_Киргизия  \
# 20569                      0                     0
# 20570                      0                     0
# 20571                      0                     0
# 20572                      0                     0
# 20573                      0                     0
#
#        NATIONALITY_Российская Федерация  NATIONALITY_Таджикистан  \
# 20569                                 1                        0
# 20570                                 0                        0
# 20571                                 1                        0
# 20572                                 1                        0
# 20573                                 1                        0
#
#        NATIONALITY_Туркмения  NATIONALITY_Узбекистан  NATIONALITY_Украина  \
# 20569                      0                       0                    0
# 20570                      0                       0                    0
# 20571                      0                       0                    0
# 20572                      0                       0                    0
# 20573                      0                       0                    0
#
#        NATIONALITY_другая страна  MACRO_BIRTH_PLACE_архангельск и ао  \
# 20569                          0                                   0
# 20570                          0                                   0
# 20571                          0                                   0
# 20572                          0                                   0
# 20573                          0                                   0
#
#        MACRO_BIRTH_PLACE_белоруссия  MACRO_BIRTH_PLACE_волгоград и во  \
# 20569                             0                                 0
# 20570                             1                                 0
# 20571                             0                                 0
# 20572                             0                                 0
# 20573                             0                                 0
#
#        MACRO_BIRTH_PLACE_воронеж и во  MACRO_BIRTH_PLACE_вьетнам  \
# 20569                               0                          0
# 20570                               0                          0
# 20571                               0                          0
# 20572                               0                          0
# 20573                               0                          0
#
#        MACRO_BIRTH_PLACE_другая страна  MACRO_BIRTH_PLACE_другой город (РФ)  \
# 20569                                0                                    0
# 20570                                0                                    0
# 20571                                0                                    1
# 20572                                0                                    0
# 20573                                0                                    1
#
#        MACRO_BIRTH_PLACE_екатеринбург и со  MACRO_BIRTH_PLACE_ижевск и ио  \
# 20569                                    0                              0
# 20570                                    0                              0
# 20571                                    0                              0
# 20572                                    0                              0
# 20573                                    0                              0
#
#        MACRO_BIRTH_PLACE_иркутс и ио  MACRO_BIRTH_PLACE_казань и рт  \
# 20569                              0                              0
# 20570                              0                              0
# 20571                              0                              0
# 20572                              0                              1
# 20573                              0                              0
#
#        MACRO_BIRTH_PLACE_казахстан  MACRO_BIRTH_PLACE_киргизия  \
# 20569                            0                           0
# 20570                            0                           0
# 20571                            0                           0
# 20572                            0                           0
# 20573                            0                           0
#
#        MACRO_BIRTH_PLACE_кнр  MACRO_BIRTH_PLACE_красноярск и кк  \
# 20569                      0                                  0
# 20570                      0                                  0
# 20571                      0                                  0
# 20572                      0                                  0
# 20573                      0                                  0
#
#        MACRO_BIRTH_PLACE_москва и мо  MACRO_BIRTH_PLACE_мурманск и мо  \
# 20569                              0                                0
# 20570                              0                                0
# 20571                              0                                0
# 20572                              0                                0
# 20573                              0                                0
#
#        MACRO_BIRTH_PLACE_нижний новгород и но  \
# 20569                                       0
# 20570                                       0
# 20571                                       0
# 20572                                       0
# 20573                                       0
#
#        MACRO_BIRTH_PLACE_новосибирск и но  MACRO_BIRTH_PLACE_оренбург и оо  \
# 20569                                   0                                0
# 20570                                   0                                0
# 20571                                   0                                0
# 20572                                   0                                0
# 20573                                   0                                0
#
#        MACRO_BIRTH_PLACE_пермь и пк  MACRO_BIRTH_PLACE_петрозаводск и рк  \
# 20569                             0                                    0
# 20570                             0                                    0
# 20571                             0                                    0
# 20572                             0                                    0
# 20573                             0                                    0
#
#        MACRO_BIRTH_PLACE_ростов-на-дону и ро  MACRO_BIRTH_PLACE_самара и со  \
# 20569                                      0                              0
# 20570                                      0                              0
# 20571                                      0                              0
# 20572                                      0                              0
# 20573                                      0                              0
#
#        MACRO_BIRTH_PLACE_санкт-петербург и ло  MACRO_BIRTH_PLACE_саратов и со  \
# 20569                                       1                               0
# 20570                                       0                               0
# 20571                                       0                               0
# 20572                                       0                               0
# 20573                                       0                               0
#
#        MACRO_BIRTH_PLACE_таджикистан  MACRO_BIRTH_PLACE_томск и то  \
# 20569                              0                             0
# 20570                              0                             0
# 20571                              0                             0
# 20572                              0                             0
# 20573                              0                             0
#
#        MACRO_BIRTH_PLACE_туркмения  MACRO_BIRTH_PLACE_узбекистан  \
# 20569                            0                             0
# 20570                            0                             0
# 20571                            0                             0
# 20572                            0                             0
# 20573                            0                             0
#
#        MACRO_BIRTH_PLACE_украина  MACRO_BIRTH_PLACE_уфа и рб  \
# 20569                          0                           0
# 20570                          0                           0
# 20571                          0                           0
# 20572                          0                           0
# 20573                          0                           0
#
#        MACRO_BIRTH_PLACE_челябинск и чо  SCHOLARSHIP_TYPE_Бронзовый ЕГЭ  \
# 20569                                 0                               0
# 20570                                 0                               0
# 20571                                 0                               0
# 20572                                 0                               0
# 20573                                 0                               0
#
#        SCHOLARSHIP_TYPE_Золотой ЕГЭ  SCHOLARSHIP_TYPE_Золотой Олимпиада  \
# 20569                             0                                   0
# 20570                             0                                   0
# 20571                             0                                   0
# 20572                             0                                   1
# 20573                             0                                   0
#
#        SCHOLARSHIP_TYPE_Серебряный ЕГЭ  SCHOLARSHIP_TYPE_Серебряный Олимпиада  \
# 20569                                1                                      0
# 20570                                0                                      0
# 20571                                0                                      0
# 20572                                0                                      0
# 20573                                0                                      0
#
#        SCHOLARSHIP_TYPE_nan  DORMITORY_FOR_STUDY_0.0  DORMITORY_FOR_STUDY_1.0  \
# 20569                     0                        1                        0
# 20570                     1                        0                        1
# 20571                     1                        0                        1
# 20572                     0                        0                        1
# 20573                     1                        0                        1
#
#        DORMITORY_FOR_STUDY_nan
# 20569                        0
# 20570                        0
# 20571                        0
# 20572                        0
# 20573                        0

# %% [markdown]
# ### Drop rows with NaN

# %%
df = df[df.MARKS_MEAN_SEM_1.notna()]

# %%
df.shape
# Out:
# (18233, 121)

# %% [markdown]
# ### Drop unused columns

# %%
DROP_COLS = ["HONS_TARGET", # Whether student had diploma with honours, not available at admission.
             "DROPPED_TARGET", # Whether student dropped out or not, not available at admission.
             "ISU_ID", # Id, needed for technical purposes, does not help prediction.
             "MARKS_MEAN_SEM_2", # Grades at 2nd semester, not available at admission.
             "CURRENT_STATUS", # Technical feature, does not help prediction.
             "REGION_ID", # Duplicates other features
            ]

# %%
filtered_df = df.drop(columns=DROP_COLS)

# %% [markdown]
# ### Translate column names in English

# %%
original_column_names = list(filtered_df.columns)

# %%
original_column_names[30]
# Out:
# 'ADMISSION_COND_без вступительных испытаний'

# %%
filtered_df = filtered_df.rename(columns=config.COLS_TRANSLATION)

# %%
filtered_df
# Out:
#        GENDER  ADMITTED_EXAMS_SUM  RUSSIAN_LANG  MATH  PHYSICS  CHEMISTRY  \
# 4           0               230.0          84.0  77.0     71.0       78.0
# 5           1               230.0          84.0  77.0     71.0       78.0
# 6           1               230.0          84.0  77.0     71.0       78.0
# 14          1               230.0          84.0  77.0     71.0       78.0
# 16          1               230.0          84.0  77.0     71.0       78.0
# ...       ...                 ...           ...   ...      ...        ...
# 20569       1               286.0          98.0  88.0     86.0       86.0
# 20570       1               247.0          86.0  78.0     80.0       79.0
# 20571       0               257.0          91.0  82.0     86.0       86.0
# 20572       1               252.0          86.0  72.0     86.0       86.0
# 20573       1               246.0          85.0  78.0     86.0       86.0
#
#        FOREIGN_LANG  INFORMATICS  SOCIAL_STUDIES  DROPPED_BEFORE  START_YEAR  \
# 4              77.0         67.0            70.5             0.0  2011-09-01
# 5              77.0         67.0            70.5             0.0  2013-09-01
# 6              77.0         67.0            70.5             2.0  2004-09-01
# 14             77.0         67.0            70.5             0.0  2007-09-01
# 16             77.0         67.0            70.5             0.0  2012-09-01
# ...             ...          ...             ...             ...         ...
# 20569          88.0        100.0            78.0             0.0  2018-09-01
# 20570          88.5         84.0            66.0             0.0  2017-09-01
# 20571          88.0         84.0            78.0             0.0  2018-09-01
# 20572          88.0        100.0            78.0             0.0  2018-09-01
# 20573          88.0         83.0            78.0             0.0  2018-09-01
#
#        AGE_AT_START  MARKS_MEAN_SEM_1  PROGRAM_01  PROGRAM_09  PROGRAM_10  \
# 4              46.0          3.250000           0           0           0
# 5              26.0          3.400000           0           0           0
# 6              16.0          3.666667           0           0           0
# 14             17.0          3.000000           0           0           0
# 16             21.0          4.000000           0           0           0
# ...             ...               ...         ...         ...         ...
# 20569          18.0          4.200000           1           0           0
# 20570          17.0          3.750000           0           0           0
# 20571          18.0          4.750000           0           0           0
# 20572          18.0          4.000000           1           0           0
# 20573          17.0          4.500000           0           0           0
#
#        PROGRAM_11  PROGRAM_12  PROGRAM_13  PROGRAM_14  PROGRAM_15  PROGRAM_16  \
# 4               0           0           0           0           0           0
# 5               0           0           0           0           0           0
# 6               0           0           0           0           0           0
# 14              0           0           0           0           0           0
# 16              0           0           0           0           0           0
# ...           ...         ...         ...         ...         ...         ...
# 20569           0           0           0           0           0           0
# 20570           0           0           0           0           0           0
# 20571           0           1           0           0           0           0
# 20572           0           0           0           0           0           0
# 20573           0           1           0           0           0           0
#
#        PROGRAM_18  PROGRAM_19  PROGRAM_23  PROGRAM_24  PROGRAM_27  PROGRAM_38  \
# 4               0           0           0           0           0           0
# 5               0           0           0           0           0           0
# 6               0           0           0           0           0           0
# 14              0           0           0           0           0           0
# 16              0           0           0           0           0           0
# ...           ...         ...         ...         ...         ...         ...
# 20569           0           0           0           0           0           0
# 20570           0           0           0           0           0           0
# 20571           0           0           0           0           0           0
# 20572           0           0           0           0           0           0
# 20573           0           0           0           0           0           0
#
#        PROGRAM_44  PROGRAM_45  ADMISSION_COND_without entrance exams  \
# 4               0           0                                      0
# 5               0           0                                      0
# 6               0           0                                      0
# 14              0           0                                      0
# 16              0           0                                      0
# ...           ...         ...                                    ...
# 20569           0           0                                      0
# 20570           0           0                                      0
# 20571           0           0                                      0
# 20572           0           0                                      1
# 20573           0           0                                      0
#
#        ADMISSION_COND_on budget place by special quota  \
# 4                                                    0
# 5                                                    0
# 6                                                    0
# 14                                                   0
# 16                                                   0
# ...                                                ...
# 20569                                                0
# 20570                                                0
# 20571                                                0
# 20572                                                0
# 20573                                                0
#
#        ADMISSION_COND_on budget place by target quota  \
# 4                                                   0
# 5                                                   0
# 6                                                   0
# 14                                                  0
# 16                                                  0
# ...                                               ...
# 20569                                               0
# 20570                                               0
# 20571                                               0
# 20572                                               0
# 20573                                               0
#
#        ADMISSION_COND_on allocated budget place (Crimea)  \
# 4                                                      0
# 5                                                      0
# 6                                                      0
# 14                                                     0
# 16                                                     0
# ...                                                  ...
# 20569                                                  0
# 20570                                                  0
# 20571                                                  0
# 20572                                                  0
# 20573                                                  0
#
#        ADMISSION_COND_on contractual basis  \
# 4                                        0
# 5                                        0
# 6                                        0
# 14                                       0
# 16                                       0
# ...                                    ...
# 20569                                    0
# 20570                                    0
# 20571                                    0
# 20572                                    0
# 20573                                    0
#
#        ADMISSION_COND_by regular admission  RUSSIAN_LANG_BIN  MATH_BIN  \
# 4                                        0                 0         0
# 5                                        0                 0         0
# 6                                        0                 0         0
# 14                                       0                 0         0
# 16                                       0                 0         0
# ...                                    ...               ...       ...
# 20569                                    1                 1         1
# 20570                                    0                 0         0
# 20571                                    1                 1         1
# 20572                                    0                 1         1
# 20573                                    1                 1         1
#
#        PHYSICS_BIN  CHEMISTRY_BIN  FOREIGN_LANG_BIN  INFORMATICS_BIN  \
# 4                0              0                 0                0
# 5                0              0                 0                0
# 6                0              0                 0                0
# 14               0              0                 0                0
# 16               0              0                 0                0
# ...            ...            ...               ...              ...
# 20569            0              0                 0                1
# 20570            0              0                 0                0
# 20571            1              0                 0                1
# 20572            0              0                 0                1
# 20573            0              0                 0                1
#
#        SOCIAL_STUDIES_BIN  Russian language  Mathematics  Biology  \
# 4                       0                 0            0        0
# 5                       0                 0            0        0
# 6                       0                 0            0        0
# 14                      0                 0            0        0
# 16                      0                 0            0        0
# ...                   ...               ...          ...      ...
# 20569                   0                 1            0        0
# 20570                   0                 0            0        0
# 20571                   0                 1            0        0
# 20572                   0                 0            0        0
# 20573                   0                 1            0        0
#
#        Foreign language  Physics  Informatics  nan  Social studies  Chemistry  \
# 4                     0        0            0    1               0          0
# 5                     0        0            0    1               0          0
# 6                     0        0            0    1               0          0
# 14                    0        0            0    1               0          0
# 16                    0        0            0    1               0          0
# ...                 ...      ...          ...  ...             ...        ...
# 20569                 0        0            0    0               0          0
# 20570                 0        0            0    1               0          0
# 20571                 0        0            0    0               0          0
# 20572                 0        0            1    0               0          0
# 20573                 0        0            0    0               0          0
#
#        ADMISSION_TYPE_100 points for olympiad  ADMISSION_TYPE_USE  \
# 4                                           0                   0
# 5                                           0                   0
# 6                                           0                   0
# 14                                          0                   0
# 16                                          0                   0
# ...                                       ...                 ...
# 20569                                       0                   1
# 20570                                       0                   0
# 20571                                       0                   1
# 20572                                       1                   0
# 20573                                       0                   1
#
#        ADMISSION_TYPE_nan  ADMITTED_SUBJECT_PRIZE_LEVEL_0.0  \
# 4                       1                                 0
# 5                       1                                 0
# 6                       1                                 0
# 14                      1                                 0
# 16                      1                                 0
# ...                   ...                               ...
# 20569                   0                                 0
# 20570                   1                                 0
# 20571                   0                                 0
# 20572                   0                                 0
# 20573                   0                                 0
#
#        ADMITTED_SUBJECT_PRIZE_LEVEL_1.0  ADMITTED_SUBJECT_PRIZE_LEVEL_2.0  \
# 4                                     0                                 0
# 5                                     0                                 0
# 6                                     0                                 0
# 14                                    0                                 0
# 16                                    0                                 0
# ...                                 ...                               ...
# 20569                                 0                                 0
# 20570                                 0                                 0
# 20571                                 0                                 0
# 20572                                 1                                 0
# 20573                                 0                                 0
#
#        ADMITTED_SUBJECT_PRIZE_LEVEL_3.0  ADMITTED_SUBJECT_PRIZE_LEVEL_4.0  \
# 4                                     0                                 0
# 5                                     0                                 0
# 6                                     0                                 0
# 14                                    0                                 0
# 16                                    0                                 0
# ...                                 ...                               ...
# 20569                                 0                                 1
# 20570                                 0                                 0
# 20571                                 0                                 1
# 20572                                 0                                 0
# 20573                                 0                                 1
#
#        ADMITTED_SUBJECT_PRIZE_LEVEL_nan  ADMITTED_EXAMS_SUM_BIN  \
# 4                                     1                       0
# 5                                     1                       0
# 6                                     1                       0
# 14                                    1                       0
# 16                                    1                       0
# ...                                 ...                     ...
# 20569                                 0                       1
# 20570                                 1                       0
# 20571                                 0                       1
# 20572                                 0                       1
# 20573                                 0                       1
#
#        NATIONALITY_Belorussia  NATIONALITY_Vietnam  NATIONALITY_PRC  \
# 4                           0                    0                0
# 5                           0                    0                0
# 6                           0                    0                0
# 14                          0                    0                0
# 16                          0                    0                0
# ...                       ...                  ...              ...
# 20569                       0                    0                0
# 20570                       1                    0                0
# 20571                       0                    0                0
# 20572                       0                    0                0
# 20573                       0                    0                0
#
#        NATIONALITY_Kazakhstan  NATIONALITY_Kyrgyzstan  \
# 4                           0                       0
# 5                           0                       0
# 6                           0                       0
# 14                          0                       0
# 16                          0                       0
# ...                       ...                     ...
# 20569                       0                       0
# 20570                       0                       0
# 20571                       0                       0
# 20572                       0                       0
# 20573                       0                       0
#
#        NATIONALITY_Russian Federation  NATIONALITY_Tajikistan  \
# 4                                   1                       0
# 5                                   1                       0
# 6                                   1                       0
# 14                                  1                       0
# 16                                  1                       0
# ...                               ...                     ...
# 20569                               1                       0
# 20570                               0                       0
# 20571                               1                       0
# 20572                               1                       0
# 20573                               1                       0
#
#        NATIONALITY_Turkmenistan  NATIONALITY_Uzbekistan  NATIONALITY_Ukraine  \
# 4                             0                       0                    0
# 5                             0                       0                    0
# 6                             0                       0                    0
# 14                            0                       0                    0
# 16                            0                       0                    0
# ...                         ...                     ...                  ...
# 20569                         0                       0                    0
# 20570                         0                       0                    0
# 20571                         0                       0                    0
# 20572                         0                       0                    0
# 20573                         0                       0                    0
#
#        NATIONALITY_another country  MACRO_BIRTH_PLACE_arkhangelsk  \
# 4                                0                              0
# 5                                0                              0
# 6                                0                              0
# 14                               0                              0
# 16                               0                              0
# ...                            ...                            ...
# 20569                            0                              0
# 20570                            0                              0
# 20571                            0                              0
# 20572                            0                              0
# 20573                            0                              0
#
#        MACRO_BIRTH_PLACE_belorussia  MACRO_BIRTH_PLACE_volgograd  \
# 4                                 0                            0
# 5                                 0                            0
# 6                                 0                            0
# 14                                0                            0
# 16                                0                            0
# ...                             ...                          ...
# 20569                             0                            0
# 20570                             1                            0
# 20571                             0                            0
# 20572                             0                            0
# 20573                             0                            0
#
#        MACRO_BIRTH_PLACE_voronezh  MACRO_BIRTH_PLACE_vietnam  \
# 4                               0                          0
# 5                               0                          0
# 6                               0                          0
# 14                              0                          0
# 16                              0                          0
# ...                           ...                        ...
# 20569                           0                          0
# 20570                           0                          0
# 20571                           0                          0
# 20572                           0                          0
# 20573                           0                          0
#
#        MACRO_BIRTH_PLACE_another country  \
# 4                                      0
# 5                                      0
# 6                                      0
# 14                                     0
# 16                                     0
# ...                                  ...
# 20569                                  0
# 20570                                  0
# 20571                                  0
# 20572                                  0
# 20573                                  0
#
#        MACRO_BIRTH_PLACE_another city (Russia)  \
# 4                                            1
# 5                                            0
# 6                                            1
# 14                                           1
# 16                                           1
# ...                                        ...
# 20569                                        0
# 20570                                        0
# 20571                                        1
# 20572                                        0
# 20573                                        1
#
#        MACRO_BIRTH_PLACE_ekaterinburg  MACRO_BIRTH_PLACE_izhevsk  \
# 4                                   0                          0
# 5                                   0                          0
# 6                                   0                          0
# 14                                  0                          0
# 16                                  0                          0
# ...                               ...                        ...
# 20569                               0                          0
# 20570                               0                          0
# 20571                               0                          0
# 20572                               0                          0
# 20573                               0                          0
#
#        MACRO_BIRTH_PLACE_irkutsk  MACRO_BIRTH_PLACE_kazan  \
# 4                              0                        0
# 5                              0                        0
# 6                              0                        0
# 14                             0                        0
# 16                             0                        0
# ...                          ...                      ...
# 20569                          0                        0
# 20570                          0                        0
# 20571                          0                        0
# 20572                          0                        1
# 20573                          0                        0
#
#        MACRO_BIRTH_PLACE_kazakhstan  MACRO_BIRTH_PLACE_kyrgyzstan  \
# 4                                 0                             0
# 5                                 0                             0
# 6                                 0                             0
# 14                                0                             0
# 16                                0                             0
# ...                             ...                           ...
# 20569                             0                             0
# 20570                             0                             0
# 20571                             0                             0
# 20572                             0                             0
# 20573                             0                             0
#
#        MACRO_BIRTH_PLACE_prc  MACRO_BIRTH_PLACE_kransoyarsk  \
# 4                          0                              0
# 5                          0                              0
# 6                          0                              0
# 14                         0                              0
# 16                         0                              0
# ...                      ...                            ...
# 20569                      0                              0
# 20570                      0                              0
# 20571                      0                              0
# 20572                      0                              0
# 20573                      0                              0
#
#        MACRO_BIRTH_PLACE_moscow  MACRO_BIRTH_PLACE_murmansk  \
# 4                             0                           0
# 5                             0                           0
# 6                             0                           0
# 14                            0                           0
# 16                            0                           0
# ...                         ...                         ...
# 20569                         0                           0
# 20570                         0                           0
# 20571                         0                           0
# 20572                         0                           0
# 20573                         0                           0
#
#        MACRO_BIRTH_PLACE_nizhny_novgorod  MACRO_BIRTH_PLACE_novosibirsk  \
# 4                                      0                              0
# 5                                      0                              0
# 6                                      0                              0
# 14                                     0                              0
# 16                                     0                              0
# ...                                  ...                            ...
# 20569                                  0                              0
# 20570                                  0                              0
# 20571                                  0                              0
# 20572                                  0                              0
# 20573                                  0                              0
#
#        MACRO_BIRTH_PLACE_orenburg  MACRO_BIRTH_PLACE_perm  \
# 4                               0                       0
# 5                               0                       0
# 6                               0                       0
# 14                              0                       0
# 16                              0                       0
# ...                           ...                     ...
# 20569                           0                       0
# 20570                           0                       0
# 20571                           0                       0
# 20572                           0                       0
# 20573                           0                       0
#
#        MACRO_BIRTH_PLACE_petrozavodsk  MACRO_BIRTH_PLACE_rostov-on-don  \
# 4                                   0                                0
# 5                                   0                                0
# 6                                   0                                0
# 14                                  0                                0
# 16                                  0                                0
# ...                               ...                              ...
# 20569                               0                                0
# 20570                               0                                0
# 20571                               0                                0
# 20572                               0                                0
# 20573                               0                                0
#
#        MACRO_BIRTH_PLACE_samara  MACRO_BIRTH_PLACE_saint-petersburg  \
# 4                             0                                   0
# 5                             0                                   1
# 6                             0                                   0
# 14                            0                                   0
# 16                            0                                   0
# ...                         ...                                 ...
# 20569                         0                                   1
# 20570                         0                                   0
# 20571                         0                                   0
# 20572                         0                                   0
# 20573                         0                                   0
#
#        MACRO_BIRTH_PLACE_saratov  MACRO_BIRTH_PLACE_tajikistan  \
# 4                              0                             0
# 5                              0                             0
# 6                              0                             0
# 14                             0                             0
# 16                             0                             0
# ...                          ...                           ...
# 20569                          0                             0
# 20570                          0                             0
# 20571                          0                             0
# 20572                          0                             0
# 20573                          0                             0
#
#        MACRO_BIRTH_PLACE_tomsk  MACRO_BIRTH_PLACE_turkmenistan  \
# 4                            0                               0
# 5                            0                               0
# 6                            0                               0
# 14                           0                               0
# 16                           0                               0
# ...                        ...                             ...
# 20569                        0                               0
# 20570                        0                               0
# 20571                        0                               0
# 20572                        0                               0
# 20573                        0                               0
#
#        MACRO_BIRTH_PLACE_uzbekistan  MACRO_BIRTH_PLACE_ukraine  \
# 4                                 0                          0
# 5                                 0                          0
# 6                                 0                          0
# 14                                0                          0
# 16                                0                          0
# ...                             ...                        ...
# 20569                             0                          0
# 20570                             0                          0
# 20571                             0                          0
# 20572                             0                          0
# 20573                             0                          0
#
#        MACRO_BIRTH_PLACE_ufa  MACRO_BIRTH_PLACE_chelyabinsk  \
# 4                          0                              0
# 5                          0                              0
# 6                          0                              0
# 14                         0                              0
# 16                         0                              0
# ...                      ...                            ...
# 20569                      0                              0
# 20570                      0                              0
# 20571                      0                              0
# 20572                      0                              0
# 20573                      0                              0
#
#        SCHOLARSHIP_TYPE_Bronze USE  SCHOLARSHIP_TYPE_Gold USE  \
# 4                                0                          0
# 5                                0                          0
# 6                                0                          0
# 14                               0                          0
# 16                               0                          0
# ...                            ...                        ...
# 20569                            0                          0
# 20570                            0                          0
# 20571                            0                          0
# 20572                            0                          0
# 20573                            0                          0
#
#        SCHOLARSHIP_TYPE_Gold Olympiad  SCHOLARSHIP_TYPE_Silver USE  \
# 4                                   0                            0
# 5                                   0                            0
# 6                                   0                            0
# 14                                  0                            0
# 16                                  0                            0
# ...                               ...                          ...
# 20569                               0                            1
# 20570                               0                            0
# 20571                               0                            0
# 20572                               1                            0
# 20573                               0                            0
#
#        SCHOLARSHIP_TYPE_Silver Olympiad  SCHOLARSHIP_TYPE_nan  \
# 4                                     0                     1
# 5                                     0                     1
# 6                                     0                     1
# 14                                    0                     1
# 16                                    0                     1
# ...                                 ...                   ...
# 20569                                 0                     0
# 20570                                 0                     1
# 20571                                 0                     1
# 20572                                 0                     0
# 20573                                 0                     1
#
#        DORMITORY_FOR_STUDY_0.0  DORMITORY_FOR_STUDY_1.0  \
# 4                            0                        0
# 5                            1                        0
# 6                            0                        0
# 14                           0                        0
# 16                           0                        0
# ...                        ...                      ...
# 20569                        1                        0
# 20570                        0                        1
# 20571                        0                        1
# 20572                        0                        1
# 20573                        0                        1
#
#        DORMITORY_FOR_STUDY_nan
# 4                            1
# 5                            0
# 6                            1
# 14                           1
# 16                           1
# ...                        ...
# 20569                        0
# 20570                        0
# 20571                        0
# 20572                        0
# 20573                        0
#
# [18233 rows x 115 columns]

# %%
filtered_df.columns[filtered_df.isna().any()]
# Out:
# Index([], dtype='object')

# %%
filtered_df = filtered_df[filtered_df.AGE_AT_START.notna()]

# %%
filtered_df.shape
# Out:
# (18233, 115)

# %%
target = filtered_df.MARKS_MEAN_SEM_1
final_df = filtered_df.drop(columns=['MARKS_MEAN_SEM_1'])

# %%
final_df['YEAR'] = final_df.START_YEAR.map(lambda x: int(x.split('-')[0]))

# %%
final_df.drop(columns=['START_YEAR'], inplace=True)

# %%
def get_x_y_until_year(df, target, year_predicted):
    target_train = target[df.YEAR < year_predicted]
    target_test = target[df.YEAR == year_predicted]
    
#     print('y shape: (train, test)')
#     print(target_train.shape, target_test.shape)
    
    df_train = final_df[df.YEAR < year_predicted]
    df_test = final_df[df.YEAR == year_predicted]

    df_train.drop(columns=['YEAR'], inplace=True)
    df_test.drop(columns=['YEAR'], inplace=True)

#     print('X shape: (train, test)')
#     print(df_train.shape, df_test.shape)
    
    X_train = df_train.to_numpy()
    y_train = target_train.to_numpy()
    X_test = df_test.to_numpy()
    y_test = target_test.to_numpy()
    
#     print('Check nans:')
#     print(np.any(np.isnan(X_train)), np.any(np.isnan(y_train)), np.any(np.isnan(X_test)), np.any(np.isnan(y_test)))
    
    return X_train, y_train, X_test, y_test

# %%
def rmse(y_pred, y_true):
    return np.sqrt(mean_squared_error(y_pred=y_pred, y_true=y_true))

# %% [markdown]
# ### Check model assumptions
#
# To check if LinearRegression is a good choice of a model we check model assumptions:
# 1) Residuals are normally distributed
#
# 2) Residuals are heteroscedastic

# %%
scaler = StandardScaler()
X_train, y_train, X_test, y_test = get_x_y_until_year(final_df, target, 2015)
X_norm_train = scaler.fit_transform(X_train)
X_norm_test = scaler.fit_transform(X_test)

clf = Lasso(alpha=0.0001, tol=0.001)
clf.fit(X_norm_train, y_train)


y_pred = clf.predict(X_norm_train)

residuals = y_pred - y_train
# Out:
# E:\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
plt.hist(residuals, bins=20);

# %% [markdown]
# ## Check homeoscedasticity
# To do this, plot residuals againts fitted values to see if there is correlation.

# %%
plt.scatter(y_pred, residuals)

# %%
import scipy.stats

scipy.stats.pearsonr(y_pred, residuals)
# Out:
# (-0.0006656907595281678, 0.9617777642586818)

# %% [markdown]
# The value of -0.0006 can be considered as no correlation. The plot does look strange though.

# %% [markdown]
# ### Train Linear regression
#
# Train on data before a given year, predict data in the given year.

# %%
scaler = StandardScaler()


for year in [2015, 2016, 2017]:
    print(f"Predicting student performance for students admitted in {year}")
    X_train, y_train, X_test, y_test = get_x_y_until_year(final_df, target, year)
    X_norm_train = scaler.fit_transform(X_train)
    X_norm_test = scaler.fit_transform(X_test)
    
    clf = Lasso(alpha=0.000001, tol=0.001)
    clf.fit(X_norm_train, y_train)
    
    print(rmse(clf.predict(X_norm_test), y_test))
    print('---')
# Out:
# Predicting student performance for students admitted in 2015
# E:\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# E:\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.01985065044619, tolerance: 1.7408399649919293
#   model = cd_fast.enet_coordinate_descent(
# E:\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# 0.5199102717330629
# ---
# Predicting student performance for students admitted in 2016
# E:\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 989.2385228921382, tolerance: 2.59711020825219
#   model = cd_fast.enet_coordinate_descent(
# E:\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# 0.582255221693348
# ---
# Predicting student performance for students admitted in 2017
# 0.5893123192136697
# ---
# E:\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 344.4457956990034, tolerance: 3.2409197410418167
#   model = cd_fast.enet_coordinate_descent(

# %%
np.sqrt(mean_squared_error(y_pred=clf.predict(X_norm_test), y_true=y_test))
# Out:
# 0.5893123192136697

# %% [markdown]
# ### Feature importance
#
# To assess the importance of various features we run cross-validation on our training data and average the feature weights.

# %%
X_train, y_train, X_test, y_test = get_x_y_until_year(final_df, target, 2017)
X_norm_train = scaler.fit_transform(X_train)
X_norm_test = scaler.fit_transform(X_test)
# Out:
# E:\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
clf = Lasso(alpha=0.0001, tol=0.001)

output = cross_validate(
    clf,
    X_norm_train,
    y_train,
    scoring='neg_root_mean_squared_error',
    cv=12,
    return_estimator=True,
);
# Out:
# E:\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.790890693787787, tolerance: 2.9395993956327535
#   model = cd_fast.enet_coordinate_descent(

# %%
coefficients = [cl.coef_ for cl in output['estimator']]
coefficients = np.stack(coefficients)
cv_coefs = np.mean(coefficients, axis=0)

# %%
sorted_coef_indices = np.flip(np.argsort(np.abs(cv_coefs)))

columns = final_df.columns.to_numpy()

# %%
first_k = 20
large_coefs = [cv_coefs[ind] for ind in sorted_coef_indices[:first_k]]
large_column_names = [columns[ind] for ind in sorted_coef_indices[:first_k]]

# %%
fig, ax = plt.subplots(1,1, figsize=(12,8))

x = list(range(len(large_coefs)))
barlist = ax.barh(x, large_coefs)
for rectangle in barlist:
    if rectangle._width < 0:
        rectangle.set_color('C1')
ax.set_xlabel('Regression coefficient')


plt.yticks(x, large_column_names)
plt.gca().invert_yaxis()
plt.tight_layout()
